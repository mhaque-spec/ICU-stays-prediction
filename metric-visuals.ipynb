# %%
r2_history = [0.24045267511282498, 
                   0.31365686155465533, 
                   0.32900594471921396,
                   0.35656774242714573,
                   0.44737872822363345,
                   0.442734139909973,
                   0.4555346002421711,
                   0.4759623787912787,
                   0.49494732159027144]

mae_history = [3.291751058990574, 
               3.115226700387827,
               2.955848749963002,
               2.8713496328758414,
               2.766892816419612,
               2.769401368301026,
               2.8911060433295326,
               2.616622043863542,
               2.6081464248695676]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
rc = {'figure.figsize':(10,5),
      'axes.facecolor':'white',
      'axes.grid' : True,
      'grid.color': '.8',
      'font.size' : 15,
      'axes.facecolor':'mintcream', 
      'figure.facecolor':'mintcream'}
plt.rcParams.update(rc)

# %%
sns.set_palette("husl")
sns.regplot(x=list(range(0,len(r2_history))),y=r2_history)#,scatter_kws={"color": "black"}, line_kws={"color": "red"})
plt.title('R squared Changes vs Model version')
plt.xlabel('Model Version No')
plt.ylabel('R squared value')
sns.despine(bottom = True, left = True)
plt.show()

# %%
sns.set_palette("muted")
sns.regplot(x=list(range(0,len(r2_history))),y=mae_history)
plt.title('Mean absolute error vs Model version')
plt.xlabel('Model Version No')
plt.ylabel('Mean absolute error')
sns.despine(bottom = True, left = True)
plt.show()
